# %% [markdown]
# <a href="https://colab.research.google.com/github/EOREUA/EOREUA/blob/main/Snippets_Sheets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Saving data to Google Sheets
#
#
# This snippet uses the open-source [gspread](https://github.com/burnash/gspread) library for interacting with Sheets.

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

sh = gc.create('A new spreadsheet')

# Open our new sheet and add some data.
worksheet = gc.open('A new spreadsheet').sheet1

cell_list = worksheet.range('A1:C2')

import random
for cell in cell_list:
  cell.value = random.randint(1, 10)

worksheet.update_cells(cell_list)
# Go to https://sheets.google.com to see your new spreadsheet.

# %% [markdown]
# # Importing data from Google Sheets

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

worksheet = gc.open('test').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
# [['', 'https://zakon.rada.gov.ua/laws/show/z1574-05', '', '', 'Про затвердження Положення про порядок і форму ведення реєстру \nрадіоелектронних засобів та випромінювальних пристроїв, що можуть \nзастосовуватися на території...', 'Про затвердження Положення про порядок і форму ведення реєстру \nрадіоелектронних засобів та випромінювальних пристроїв, що можуть \nзастосовуватися на території...', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', 'https://zakon.rada.gov.ua/laws/show/355-2017-%D0%BF#n79', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', 'https://zakon.rada.gov.ua/laws/show/1770-14', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', 'https://nkrzi.gov.ua/index.php?r=site/index&pg=59&id=4183&language=uk', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', 'https://nkrzi.gov.ua/index.p
# ...
